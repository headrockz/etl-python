# %%
import pandas as pd

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5747           CAMPINAS            SP                 SBKP     2020-12-29
# 5748  LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749     RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750          VICENTINA            MS                 ****     2020-12-31
# 5751     RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.loc[df.ocorrencia_aerodromo == '####']
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 635               43915               43915                INCIDENTE
# 3472              60677               60677          INCIDENTE GRAVE
# 3575              60894               60894                 ACIDENTE
# 3624              61042               61042                 ACIDENTE
# 3766              65799               65799                 ACIDENTE
# 3872              66223               66223                 ACIDENTE
# 3998              66667               66667                 ACIDENTE
# 4004              66675               66675                 ACIDENTE
# 4075              66903               66903                INCIDENTE
# 4442              77826               77826                 ACIDENTE
# 4563              78055               78055          INCIDENTE GRAVE
# 4823              78550               78550                 ACIDENTE
# 5737              79748               79748                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 635              VILA VELHA            ES                 ####     2011-02-17
# 3472          CAMPO FLORIDO            MG                 ####     2016-01-05
# 3575               BEBERIBE            CE                 ####     2016-03-19
# 3624         RIO DE JANEIRO            RJ                 ####     2016-04-22
# 3766                SOCORRO            SP                 ####     2016-10-08
# 3872             MONTIVIDIU            GO                 ####     2017-01-04
# 3998               ITAITUBA            PA                 ####     2017-04-21
# 4004                MARILUZ            PR                 ####     2017-04-23
# 4075                 PALMAS            TO                 ####     2017-06-13
# 4442             MONTIVIDIU            GO                 ####     2018-04-16
# 4563                  CAIRU            BA                 ####     2018-07-22
# 4823          SÃO DESIDÉRIO            BA                 ####     2019-02-23
# 5737  SANTANA DO LIVRAMENTO            RS                 ####     2020-12-23
#
#      ocorrencia_hora  total_recomendacoes
# 635         11:35:00                    0
# 3472        12:30:00                    1
# 3575        13:30:00                    0
# 3624        14:50:00                    0
# 3766        13:00:00                    0
# 3872        14:00:00                    1
# 3998        18:00:00                    0
# 4004        10:15:00                    0
# 4075        09:29:00                    0
# 4442        12:00:00                    0
# 4563        14:25:00                    2
# 4823        11:05:00                    1
# 5737        13:30:00                    0

# %%
df.replace(['**', '####', '###!', '*****', 'NULL'], pd.NA, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.fillna(10, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            2
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df['uf_bkp'] = df.ocorrencia_uf
df
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5747             79804              79804                INCIDENTE
# 5748             79757              79757          INCIDENTE GRAVE
# 5749             79802              79802                INCIDENTE
# 5750             79756              79756          INCIDENTE GRAVE
# 5751             79844              79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 <NA>     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes uf_bkp
# 0           12:00:00                    0     RJ
# 1           11:05:00                    0     PA
# 2           03:00:00                    0     RJ
# 3           17:30:00                    0     MT
# 4           19:25:00                    0     RS
# ...              ...                  ...    ...
# 5747        19:00:00                    0     SP
# 5748        18:30:00                    0     TO
# 5749        00:54:00                    0     RJ
# 5750        09:00:00                    0     MS
# 5751        13:24:00                    0     RJ
#
# [5752 rows x 10 columns]

# %%
df.drop(['uf_bkp'], axis=1, inplace=True)
df
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5747             79804              79804                INCIDENTE
# 5748             79757              79757          INCIDENTE GRAVE
# 5749             79802              79802                INCIDENTE
# 5750             79756              79756          INCIDENTE GRAVE
# 5751             79844              79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 <NA>     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
#
# [5752 rows x 9 columns]

# %%
df.dropna()
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 4                40324              40324                INCIDENTE
# 6                40215              40215                INCIDENTE
# 8                39156              39156          INCIDENTE GRAVE
# ...                ...                ...                      ...
# 5743             79824              79824                 ACIDENTE
# 5746             79769              79769          INCIDENTE GRAVE
# 5747             79804              79804                INCIDENTE
# 5749             79802              79802                INCIDENTE
# 5751             79844              79844                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1                BELÉM            PA                 SBBE     2010-01-03
# 2       RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 4              PELOTAS            RS                 SBPK     2010-01-05
# 6                COARI            AM                 SBUY     2010-01-07
# 8             CASCAVEL            PR                 SBCA     2010-01-10
# ...                ...           ...                  ...            ...
# 5743     RIO PARANAÍBA            MG                 SNRP     2020-12-28
# 5746     MANOEL URBANO            AC                 SIMB     2020-12-29
# 5747          CAMPINAS            SP                 SBKP     2020-12-29
# 5749    RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5751    RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 1           11:05:00                    0
# 2           03:00:00                    0
# 4           19:25:00                    0
# 6           18:40:00                    0
# 8           23:15:00                    2
# ...              ...                  ...
# 5743        17:00:00                    0
# 5746        18:30:00                    0
# 5747        19:00:00                    0
# 5749        00:54:00                    0
# 5751        13:24:00                    0
#
# [3403 rows x 9 columns]

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5747             79804              79804                INCIDENTE
# 5748             79757              79757          INCIDENTE GRAVE
# 5749             79802              79802                INCIDENTE
# 5750             79756              79756          INCIDENTE GRAVE
# 5751             79844              79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 <NA>     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
#
# [5751 rows x 9 columns]

# %%
df.drop_duplicates(inplace=True)
df
